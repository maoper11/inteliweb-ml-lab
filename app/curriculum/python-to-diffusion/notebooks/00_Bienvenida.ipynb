# %% [markdown]
# # 00 · Bienvenida a Inteliweb ML Lab
#
# **Objetivo:** Aprender a moverte por JupyterLab, ejecutar celdas y guardar tu progreso.
#
# **Duración estimada:** 20–35 minutos
#
# > Usa el kernel **Python - Inteliweb ML Lab**. Ejecuta cada celda con `Shift + Enter`.
#
# **Leyenda:** 📖 concepto · ▶️ ejecuta · ✏️ modifica · 🧪 práctica · ✅ resultado esperado · 🔗 relación con ComfyUI

# %% [markdown]
# ## 📖 ¿Qué es un notebook?
#
# Un notebook combina explicaciones, código ejecutable y resultados en un archivo `.ipynb`.
#
# - **Markdown:** texto, títulos y notas.
# - **Code:** instrucciones de Python.
# - **Output:** resultado de una celda de código.

# %%
mensaje = "¡Inteliweb ML Lab está funcionando!"
print(mensaje)

# %% [markdown]
# ✅ Debes ver el mensaje debajo de la celda.
#
# ## ▶️ Tu primer cálculo

# %%
pasos = 20
imagenes = 4
operaciones = pasos * imagenes
print("Operaciones estimadas:", operaciones)

# %% [markdown]
# ## ✏️ Cambia valores
#
# Modifica `pasos` o `imagenes` y vuelve a ejecutar.

# %%
nombre = "Estudiante"
tema = "modelos de difusión"
print(f"Hola, {nombre}. Empezaremos a estudiar {tema}.")

# %% [markdown]
# ## 🧪 Práctica
#
# Cambia el nombre y el tema. Después ejecuta la celda.

# %%
from pathlib import Path
print("Carpeta actual:", Path.cwd())
print("Los cursos están dentro de app/workspace/courses.")

# %% [markdown]
# ## 🔗 Relación con ComfyUI
#
# En ComfyUI conectas nodos; en Python conectas variables, funciones y objetos. En ambos casos construyes un flujo.
#
# ## ✅ Resumen
#
# Ya sabes ejecutar, modificar y guardar celdas. **Siguiente:** `01_Verificar_Entorno.ipynb`
